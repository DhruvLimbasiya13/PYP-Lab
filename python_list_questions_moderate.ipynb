# %% [markdown]
# # Python Lists – Practice Questions (Moderate Level)
# This notebook contains **practice questions only** related to **Python lists and their methods**.
# Try solving each question in the code cells provided below each question.

# %% [markdown]
# ## Question 1
# Create a list of integers. Write a program to remove all duplicate elements from the list while maintaining the original order.

# %%
# Write your solution here

# %% [markdown]
# ## Question 2
# Given a list of numbers, use list methods to:
# 1. Add a new number at the end
# 2. Insert a number at a specific index
# 3. Remove the last element
# Print the final list.

# %%
# Write your solution here

# %% [markdown]
# ## Question 3
# Write a program to find the second largest element in a list without using built-in sorting functions.

# %%
# Write your solution here

# %% [markdown]
# ## Question 4
# Given a list of strings, count how many strings have a length greater than 3 and start with a vowel.

# %%
# Write your solution here

# %% [markdown]
# ## Question 5
# Write a program that splits a list into two lists:
# - One containing even numbers
# - One containing odd numbers

# %%
# Write your solution here

# %% [markdown]
# ## Question 6
# Given two lists, write a program to:
# 1. Find common elements using list methods
# 2. Store them in a new list without duplicates

# %%
# Write your solution here

# %% [markdown]
# ## Question 7
# Write a program to rotate a list to the right by `k` positions using list slicing.

# %%
# Write your solution here

# %% [markdown]
# ## Question 8
# Given a nested list, write a program to flatten it into a single list.

# %%
# Write your solution here

# %% [markdown]
# ## Question 9
# Write a program that uses list methods to reverse a list and then sort it in ascending order.

# %%
# Write your solution here

# %% [markdown]
# ## Question 10
# Given a list of integers, replace every element with the sum of all previous elements.

# %%
# Write your solution here
