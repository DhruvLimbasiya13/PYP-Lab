# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 2</b></center>
# Dhruv Limbasiya
# 24031701027
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World..!!”

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### 02) WAP to accept your name and display a welcome message.
# #### Input: Priya
# #### Output: Hello Priya, welcome to Python Lab.

# %%
name = input("enter your name :")
print(f"hello {name} , welcome to Python Lab")
# Out:
# enter your name : Dhruv
# hello Dhruv , welcome to Python Lab

# %% [markdown]
# ### 03) WAP to accept three integers and display the numbers, their sum, and average.
# #### Input: 10 20 30
# #### Output:
# ##### Numbers: 10 20 30
# ##### Sum: 60
# ##### Average: 20.0

# %%
number1 = int(input("enter the value of number 1 :"))
number2 = int(input("enter the value of number 2 :"))
number3 = int(input("enter the value of number 3 :"))
sum = number1 + number2 + number3
average = sum/3
print(f"Number : {number1} , {number2} , {number3} \nsum : {sum} \naverage : {average}")
print(f"the sum of {number1} , {number2} , {number3} is {number1+number2+number3} and average {(number1+number2+number3)/3} .")
# Out:
# enter the value of number 1 : 10
# enter the value of number 2 : 20
# enter the value of number 3 : 30
# Number : 10 , 20 , 30
# sum : 60
# average : 20.0
# the sum of 10 , 20 , 30 is 60 and average 20.0 .

# %% [markdown]
# ### 04) WAP to accept name (string), age (int), and percentage (float).
# #### Input : Riya,18,92.5
# #### Output :
# ##### Name: Riya  Type: <class 'str'>
# ##### Age: 18  Type: <class 'int'>
# ##### Percentage: 92.5  Type: <class 'float'>

# %%
name=input("Enter Name: ")
age=int(input("Enter Age: "))
percentage=float(input("Enter percentage: "))
print(f"Name:{name} Type:{type(name)}\nAge:{age} Type:{type(age)}\nPercentage:{percentage} Type:{type(percentage)}\n")
# Out:
# Enter Name:  Dhruv
# Enter Age:  20
# Enter percentage:  94.35
# Name:Dhruv Type:<class 'str'>
# Age:20 Type:<class 'int'>
# Percentage:94.35 Type:<class 'float'>

# %% [markdown]
# ### 05) WAP to print folowing message using custom separator and end.
# #### Ouutput : Python | Programming | Basics###

# %%
print("Python" , "Programming" , "Basics" , sep="|" , end="###")
# Out:
# Python|Programming|Basics###

# %% [markdown]
# ### 06) WAP to accept a value and display its value, type, and memory id.
# #### Input : hello
# #### Output :
# ##### Value: hello
# ##### Type: <class 'str'>
# ##### ID: 140712345678912

# %%
value = input("enter something here :")
print(f"type : {type(value)}\nID : {id(value)}")
# Out:
# enter something here : Dhruv
# type : <class 'str'>
# ID : 1236589841408

# %% [markdown]
# ### 07) WAP to assign a value to a variable, print id, reassign a new value, and print id again.
# #### Output :
# ##### Original ID of a: 140712345678912
# ##### New ID of a: 140712345678960

# %%
variable = 2
print(f"original ID of Variable : {id(variable)}")
variable = 5
print(f"New ID of Variable : {id(variable)}")
# Out:
# original ID of Variable : 140724760196040
# New ID of Variable : 140724760196136

# %% [markdown]
# ### 08) WAP to print multiple lines using a single print().
# #### Output:
# ##### Welcome to Python
# ##### This is the second lab
# ##### Enjoy coding!

# %%
print("welcome to Python\nThis is the second lab\nEnjoy Codind!")
# Out:
# welcome to Python
# This is the second lab
# Enjoy Codind!

# %% [markdown]
# ### 09) WAP to display following table of items with proper alignment.
# #### Output :
# | Sr No | Name        | Subject | Grade | Percentage |
# | ----: | ----------- | ------- | :---: | ---------: |
# |     1 | Nisha Patel | Math    |   A   |         92 |
# |     2 | Aarav Modi  | Science |   B+  |         85 |
# |     3 | Jiya Shah   | English |   A+  |         96 |

# %%
print(f"{'SrNo':^7}{'Name':<15}{'Subject':<10}{'Grade':^10}{'Percentage':^10}")
print(f"{'1':^7}{'Nisha Patel':<15}{'Math':<10}{'A':^10}{'92':>10}")
print(f"{'2':^7}{'Aarav Modi':<15}{'Science':<10}{'B+':^10}{'85':>10}")
print(f"{'3':^7}{'Jiya Shah':<15}{'English':<10}{'A+':^10}{'96':>10}")
# Out:
#  SrNo  Name           Subject     Grade   Percentage
#    1   Nisha Patel    Math          A             92
#    2   Aarav Modi     Science       B+            85
#    3   Jiya Shah      English       A+            96

# %% [markdown]
# ### 10) WAP to accept a float number and display with 2 decimals, 3 decimals, and width 10.
# #### Input : 37.2567
# #### Output :
# ##### 2 decimals: 37.26
# ##### 3 decimals: 37.257
# ##### Width 10:      37.26

# %%
number = float(input("enter a float number :"))
print(f"2 decimal : {number:.2f}\n3 decimal : {number:.3f}\nWidth : {number:10.2f}")
# Out:
# enter a float number : 3.14159265359
# 2 decimal : 3.14
# 3 decimal : 3.142
# Width :       3.14

# %% [markdown]
# ### 11) WAP to accept two integers and display sum, difference, and product using f-strings.
# #### Input : 12 8
# #### Output :
# ##### Sum = 20
# ##### Difference = 4
# ##### Product = 96

# %%
number1 = int(input("enter the value of number 1 :"))
number2 = int(input("enter the value of number 2 :"))
sum = number1 + number2
print(f"Number : {number1} , {number2} \nsum : {sum}\nDifference : {number1-number2}\nProduct : {number1*number2}")
# Out:
# enter the value of number 1 : 12
# enter the value of number 2 : 8
# Number : 12 , 8
# sum : 20
# Difference : 4
# Product : 96

# %% [markdown]
# ### 12) WAP to accept date in dd mm yyyy format and display in multiple formats.
# #### Input : 01 12 2025
# #### Output :
# ##### 01/12/2025
# ##### 2025-12-01

# %%
day,month,year = input("enter a date (dd mm yyyy) format :").split(sep=" ")
print(day,month,year,sep="/")
print(year,month,day,sep="-")
# Out:
# enter a date (dd mm yyyy) format : 01 12 2025
# 01/12/2025
# 2025-12-01

# %% [markdown]
# ### 13) WAP to calculate area and perimeter of a circle.

# %%
radius = int(input("enter a radius :"))
area = 3.14159265359*radius*radius
perimeter = 2*3.14159265359*radius
print(f"area of radius {radius} is : {area}\nPerimeter of radius {radius} is : {perimeter}")
# Out:
# enter a radius : 3
# area of radius 3 is : 28.274333882310003
# Perimeter of radius 3 is : 18.849555921540002

# %% [markdown]
# ### 14) WAP to convert degree into Fahrenheit and vice versa.

# %%
celsius = float(input("enter Degree in Celsius to convert into Fahrenheit :"))
print(f"Fahrenheit value of {celsius} degree in Celsius is : {(celsius * 9/5) + 32}")
fahrenheit = float(input("enter Degree in Fahrenheit to convert into Celsius :"))
print(f"Celsius value of {fahrenheit} degree in Fahrenheit is : {(fahrenheit-32)*(5/9)}")
# Out:
# enter Degree in Celsius to convert into Fahrenheit : 23
# Fahrenheit value of 23.0 degree in Celsius is : 73.4
# enter Degree in Fahrenheit to convert into Celsius : 73.4
# Celsius value of 73.4 degree in Fahrenheit is : 23.000000000000004

# %% [markdown]
# ### 15) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
km = float(input("enter distance in kilometer :"))
meter = km*1000
cm = km*1000*100
feet = km *3280.84
inches = km * 39370.1
print(f"Kilometer={km}\nmeter ={meter}\nCentimeter={cm}\nfeet={feet}\ninches={inches}")
# Out:
# enter distance in kilometer : 3
# Kilometer=3.0
# meter =3000.0
# Centimeter=300000.0
# feet=9842.52
# inches=118110.29999999999
