# %% [markdown]
# # Python Lists – Hard Practice Questions (Advanced Level)
#
# This notebook contains **20 challenging questions** focused strictly on **Python lists and list methods**.
# Solve each problem using Python code in the provided cells.

# %% [markdown]
# ## Question 1
# Remove all elements that appear more than once in a list.

# %%
# Write your solution here

# %% [markdown]
# ## Question 2
# Find the maximum product of any two numbers in a list.

# %%
# Write your solution here

# %% [markdown]
# ## Question 3
# Rotate a list left by `k` positions without using extra lists.

# %%
# Write your solution here

# %% [markdown]
# ## Question 4
# Find all pairs in a list whose sum equals a given number.

# %%
# Write your solution here

# %% [markdown]
# ## Question 5
# Replace each element with the next greatest element on its right.

# %%
# Write your solution here

# %% [markdown]
# ## Question 6
# Find the longest increasing contiguous sublist.

# %%
# Write your solution here

# %% [markdown]
# ## Question 7
# Remove consecutive duplicate elements from a list.

# %%
# Write your solution here

# %% [markdown]
# ## Question 8
# Find the first repeating element in a list.

# %%
# Write your solution here

# %% [markdown]
# ## Question 9
# Split a list into `n` nearly equal parts.

# %%
# Write your solution here

# %% [markdown]
# ## Question 10
# Check if a list is a palindrome without using reverse().

# %%
# Write your solution here

# %% [markdown]
# ## Question 11
# Rearrange a list so that positive and negative numbers alternate.

# %%
# Write your solution here

# %% [markdown]
# ## Question 12
# Find the intersection of multiple lists.

# %%
# Write your solution here

# %% [markdown]
# ## Question 13
# Find missing numbers in a list containing values from 1 to n.

# %%
# Write your solution here

# %% [markdown]
# ## Question 14
# Move all zeroes to the end while maintaining order of other elements.

# %%
# Write your solution here

# %% [markdown]
# ## Question 15
# Flatten a list with arbitrary nesting depth.

# %%
# Write your solution here

# %% [markdown]
# ## Question 16
# Find the majority element (appears more than n//2 times).

# %%
# Write your solution here

# %% [markdown]
# ## Question 17
# Group elements based on their frequency.

# %%
# Write your solution here

# %% [markdown]
# ## Question 18
# Generate all possible sublists of a list.

# %%
# Write your solution here

# %% [markdown]
# ## Question 19
# Find the minimum number of swaps required to sort a list.

# %%
# Write your solution here

# %% [markdown]
# ## Question 20
# Replace elements with their rank in the list.

# %%
# Write your solution here
